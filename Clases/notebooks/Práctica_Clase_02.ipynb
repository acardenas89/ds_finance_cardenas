# %%
# 3 elevado a 2
pow(3,2)b
# Out:
# 10

# %%
# Valor absoluto
abs(-10)
# Out:
# 10

# %%
round(3.14151932,2)
# Out:
# 3.14

# %%
variable_1 = 1.1
type(variable_1)
# Out:
# float

# %%
# Concatenar variables
nombre = "Álvaro"
apellido = "Cárdenas"
nombre_completo = nombre + " " + apellido
print(nombre_completo)
# Out:
# Álvaro Cárdenas

# %%
nota = input("Que día es hoy? : ")

# %%
3.1 + 4.3
# Out:
# 7.4

# %%
persona_1, persona_2, persona_3 = "Camilita", "Andreita", "Alvarito"
persona_1
# Out:
# 'Camilita'

# %%
"Estoy viendo New Amsterdam"
# Out:
# 'Estoy viendo New Amsterdam'

# %%
print("Estoy\nviendo\nNew Amsterdam")
# Out:
# Estoy
# viendo
# New Amsterdam

# %%
s = "Creando strings en Python"

# %%
s[0]
# Out:
# 'C'

# %%
s[0:]
# Out:
# 'Creando strings en Python'

# %%
s
# Out:
# 'Creando strings en Python'

# %%
s.upper()
# Out:
# 'CREANDO STRINGS EN PYTHON'

# %%
s.lower()
# Out:
# 'creando strings en python'

# %%
s.split()
# Out:
# ['Creando', 'strings', 'en', 'Python']

# %%
lista = [1, 2.9, 'nombre', [5, 6], 4]

# %%
print(lista[0]) # 1
print(lista[1]) # 2.9
print(lista[2]) # nombre
print(lista[3]) # [5 ,6]
print(lista[1:6])
# Out:
# 1
# 2.9
# nombre
# [5, 6]
# [2.9, 'nombre', [5, 6], 4]
