# %%
# 3 elevado a 2
pow(3,2)b
# Out:
# 10

# %%
# Valor absoluto
abs(-10)
# Out:
# 10

# %%
round(3.14151932,2)
# Out:
# 3.14

# %%
variable_1 = 1.1
type(variable_1)
# Out:
# float

# %%
# Concatenar variables
nombre = "Álvaro"
apellido = "Cárdenas"
nombre_completo = nombre + " " + apellido
print(nombre_completo)
# Out:
# Álvaro Cárdenas
