# %%
print("Hola Mundo")
# Out:
# Hola Mundo

# %%
variable_1 = 1

# %%
variable_1
# Out:
# 1

# %%
fruta_1 = fruta_2 = fruta_3 = 'naranja'

# %%
fruta_1
# Out:
# 'naranja'

# %%
# Una frase
"Creando strings en Python"
# Out:
# 'Creando strings en Python'

# %%
s = "Creando strings en Python"

# %%
s[0]
# Out:
# 'C'

# %%
s[0:7]
# Out:
# 'Creando'

# %%
s.upper()
# Out:
# 'CREANDO STRINGS EN PYTHON'

# %%
s.lower()
# Out:
# 'creando strings en python'

# %%
s.split()
# Out:
# ['Creando', 'strings', 'en', 'Python']
